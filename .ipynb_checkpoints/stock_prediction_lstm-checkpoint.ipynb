# %%
import pandas as pd
import datetime as dt
from datetime import date
import matplotlib.pyplot as plt
import yfinance as yf
import numpy as np
import tensorflow as tf

# %%
#Define start day to fetch the dataset from the yahoo finance library
START = "2010-01-01"
TODAY = date.today().strftime("%Y-%m-%d")

# Define a function to load the dataset

def load_data(ticker):
    data = yf.download(ticker, START, TODAY)
    data.reset_index(inplace=True)
    return data

# %%
data = load_data('TCS.NS')
df=data
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Date   Adj Close       Close        High  \
# Ticker                                TCS.NS      TCS.NS      TCS.NS
# 0      2010-01-04 00:00:00+00:00  293.429718  375.825012  379.450012
# 1      2010-01-05 00:00:00+00:00  293.507690  375.924988  379.774994
# 2      2010-01-06 00:00:00+00:00  286.871368  367.424988  376.100006
# 3      2010-01-07 00:00:00+00:00  278.887970  357.200012  369.700012
# 4      2010-01-08 00:00:00+00:00  273.188385  349.899994  359.250000
#
# Price          Low        Open   Volume
# Ticker      TCS.NS      TCS.NS   TCS.NS
# 0       374.524994  377.399994  1963682
# 1       373.274994  377.500000  2014488
# 2       366.500000  375.924988  3349176
# 3       355.500000  367.750000  6474892
# 4       348.250000  358.000000  6048178

# %%
#Visualizing Closing Price
plt.figure(figsize=(12, 6))
plt.plot(df['Close'])
plt.title("TCS India Stock Price")
plt.xlabel("Date")
plt.ylabel("Price (INR)")
plt.grid(True)
plt.show()

# %%
df
# Out:
# Price                       Date    Adj Close        Close         High  \
# Ticker                                 TCS.NS       TCS.NS       TCS.NS
# 0      2010-01-04 00:00:00+00:00   293.429718   375.825012   379.450012
# 1      2010-01-05 00:00:00+00:00   293.507690   375.924988   379.774994
# 2      2010-01-06 00:00:00+00:00   286.871368   367.424988   376.100006
# 3      2010-01-07 00:00:00+00:00   278.887970   357.200012   369.700012
# 4      2010-01-08 00:00:00+00:00   273.188385   349.899994   359.250000
# ...                          ...          ...          ...          ...
# 3665   2024-11-08 00:00:00+00:00  4147.000000  4147.000000  4169.750000
# 3666   2024-11-11 00:00:00+00:00  4198.700195  4198.700195  4234.299805
# 3667   2024-11-12 00:00:00+00:00  4197.399902  4197.399902  4218.000000
# 3668   2024-11-13 00:00:00+00:00  4150.350098  4150.350098  4196.750000
# 3669   2024-11-14 00:00:00+00:00  4145.899902  4145.899902  4160.000000
#
# Price           Low         Open   Volume
# Ticker       TCS.NS       TCS.NS   TCS.NS
# 0        374.524994   377.399994  1963682
# 1        373.274994   377.500000  2014488
# 2        366.500000   375.924988  3349176
# 3        355.500000   367.750000  6474892
# 4        348.250000   358.000000  6048178
# ...             ...          ...      ...
# 3665    4117.649902  4155.000000  1648039
# 3666    4117.649902  4128.200195  1406487
# 3667    4164.350098  4216.000000  1587640
# 3668    4131.049805  4178.100098  1098813
# 3669    4116.450195  4135.000000  1825432
#
# [3670 rows x 7 columns]

# %%
#Plotting moving averages of 100 day
ma100 = df.Close.rolling(100).mean()
ma100
# Out:
# Ticker       TCS.NS
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 3665    4221.610991
# 3666    4225.580994
# 3667    4229.682493
# 3668    4233.078494
# 3669    4236.369492
#
# [3670 rows x 1 columns]

# %%
plt.figure(figsize = (12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')
plt.grid(True)
plt.title('Graph Of Moving Averages Of 100 Days')
# Out:
# Text(0.5, 1.0, 'Graph Of Moving Averages Of 100 Days')

# %%
#Defining 200 days moving averages and plotting comparision graph with 100 days moving averages
ma200 = df.Close.rolling(200).mean()
ma200
# Out:
# Ticker       TCS.NS
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 3665    4081.701249
# 3666    4083.271749
# 3667    4084.745748
# 3668    4085.782249
# 3669    4087.220498
#
# [3670 rows x 1 columns]

# %%
plt.figure(figsize = (12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')
plt.plot(ma200, 'g')
plt.grid(True)
plt.title('Comparision Of 100 Days And 200 Days Moving Averages')
# Out:
# Text(0.5, 1.0, 'Comparision Of 100 Days And 200 Days Moving Averages')

# %%
df.shape
# Out:
# (3670, 7)

# %%
#Spliting the dataset into training (70%) and testing (30%) set
# Splitting data into training and testing

train = pd.DataFrame(data[0:int(len(data)*0.70)])
test = pd.DataFrame(data[int(len(data)*0.70): int(len(data))])

print(train.shape)
print(test.shape)
# Out:
# (2569, 7)
# (1101, 7)

# %%
train.head()
# Out:
# Price                       Date   Adj Close       Close        High  \
# Ticker                                TCS.NS      TCS.NS      TCS.NS
# 0      2010-01-04 00:00:00+00:00  293.429718  375.825012  379.450012
# 1      2010-01-05 00:00:00+00:00  293.507690  375.924988  379.774994
# 2      2010-01-06 00:00:00+00:00  286.871368  367.424988  376.100006
# 3      2010-01-07 00:00:00+00:00  278.887970  357.200012  369.700012
# 4      2010-01-08 00:00:00+00:00  273.188385  349.899994  359.250000
#
# Price          Low        Open   Volume
# Ticker      TCS.NS      TCS.NS   TCS.NS
# 0       374.524994  377.399994  1963682
# 1       373.274994  377.500000  2014488
# 2       366.500000  375.924988  3349176
# 3       355.500000  367.750000  6474892
# 4       348.250000  358.000000  6048178

# %%
#Using MinMax scaler for normalization of the dataset
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

# %%
train_close = train.iloc[:, 4:5].values
test_close = test.iloc[:, 4:5].values

# %%
data_training_array = scaler.fit_transform(train_close)
data_training_array
# Out:
# array([[0.01671754],
#        [0.01606246],
#        [0.01251195],
#        ...,
#        [0.88968517],
#        [0.90110973],
#        [0.90014016]])

# %%
x_train = []
y_train = [] 

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100: i])
    y_train.append(data_training_array[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train.shape
# Out:
# (2469, 100, 1)

# %%
#ML Model (LSTM)
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.models import Sequential

# %%
model = Sequential()
model.add(LSTM(units = 50, activation = 'relu', return_sequences=True
              ,input_shape = (x_train.shape[1], 1)))
model.add(Dropout(0.2))


model.add(LSTM(units = 60, activation = 'relu', return_sequences=True))
model.add(Dropout(0.3))


model.add(LSTM(units = 80, activation = 'relu', return_sequences=True))
model.add(Dropout(0.4))


model.add(LSTM(units = 120, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(units = 1))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 100, 50)           10400
#
#  dropout_4 (Dropout)         (None, 100, 50)           0
#
#  lstm_5 (LSTM)               (None, 100, 60)           26640
#
#  dropout_5 (Dropout)         (None, 100, 60)           0
#
#  lstm_6 (LSTM)               (None, 100, 80)           45120
#
#  dropout_6 (Dropout)         (None, 100, 80)           0
#
#  lstm_7 (LSTM)               (None, 120)               96480
#
#  dropout_7 (Dropout)         (None, 120)               0
#
#  dense_1 (Dense)             (None, 1)                 121
#
# =================================================================
# Total params: 178,761
# Trainable params: 178,761
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Training the model
import tensorflow as tf
model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics=[tf.keras.metrics.MeanAbsoluteError()])
model.fit(x_train, y_train,epochs = 100)
# Out:
# Epoch 1/100
# 78/78 [==============================] - 17s 180ms/step - loss: 0.0480 - mean_absolute_error: 0.1531
# Epoch 2/100
# 78/78 [==============================] - 14s 183ms/step - loss: 0.0118 - mean_absolute_error: 0.0771
# Epoch 3/100
# 78/78 [==============================] - 15s 189ms/step - loss: 0.0092 - mean_absolute_error: 0.0669
# Epoch 4/100
# 78/78 [==============================] - 15s 193ms/step - loss: 0.0074 - mean_absolute_error: 0.0589
# Epoch 5/100
# 78/78 [==============================] - 15s 192ms/step - loss: 0.0071 - mean_absolute_error: 0.0577
# Epoch 6/100
# 78/78 [==============================] - 15s 189ms/step - loss: 0.0068 - mean_absolute_error: 0.0568
# Epoch 7/100
# 78/78 [==============================] - 15s 191ms/step - loss: 0.0066 - mean_absolute_error: 0.0561
# Epoch 8/100
# 78/78 [==============================] - 15s 193ms/step - loss: 0.0055 - mean_absolute_error: 0.0511
# Epoch 9/100
# 78/78 [==============================] - 16s 200ms/step - loss: 0.0056 - mean_absolute_error: 0.0514
# Epoch 10/100
# 78/78 [==============================] - 15s 194ms/step - loss: 0.0064 - mean_absolute_error: 0.0543
# Epoch 11/100
# 78/78 [==============================] - 15s 192ms/step - loss: 0.0047 - mean_absolute_error: 0.0475
# Epoch 12/100
# 78/78 [==============================] - 15s 194ms/step - loss: 0.0053 - mean_absolute_error: 0.0494
# Epoch 13/100
# 78/78 [==============================] - 15s 195ms/step - loss: 0.0045 - mean_absolute_error: 0.0467
# Epoch 14/100
# 78/78 [==============================] - 16s 202ms/step - loss: 0.0049 - mean_absolute_error: 0.0487
# Epoch 15/100
# 78/78 [==============================] - 17s 213ms/step - loss: 0.0047 - mean_absolute_error: 0.0461
# Epoch 16/100
# 78/78 [==============================] - 16s 210ms/step - loss: 0.0043 - mean_absolute_error: 0.0443
# Epoch 17/100
# 78/78 [==============================] - 17s 218ms/step - loss: 0.0042 - mean_absolute_error: 0.0446
# Epoch 18/100
# 78/78 [==============================] - 16s 200ms/step - loss: 0.0040 - mean_absolute_error: 0.0431
# Epoch 19/100
# 78/78 [==============================] - 16s 208ms/step - loss: 0.0036 - mean_absolute_error: 0.0419
# Epoch 25/100
# 78/78 [==============================] - 16s 203ms/step - loss: 0.0037 - mean_absolute_error: 0.0417
# Epoch 26/100
# 78/78 [==============================] - 16s 200ms/step - loss: 0.0031 - mean_absolute_error: 0.0400
# Epoch 27/100
# 78/78 [==============================] - 15s 197ms/step - loss: 0.0032 - mean_absolute_error: 0.0398
# Epoch 28/100
# 78/78 [==============================] - 16s 202ms/step - loss: 0.0034 - mean_absolute_error: 0.0407
# Epoch 29/100
# 78/78 [==============================] - 405s 5s/step - loss: 0.0035 - mean_absolute_error: 0.0419
# Epoch 30/100
# 78/78 [==============================] - 312s 4s/step - loss: 0.0031 - mean_absolute_error: 0.0394
# Epoch 31/100
# 78/78 [==============================] - 14s 183ms/step - loss: 0.0032 - mean_absolute_error: 0.0400
# Epoch 32/100
# 78/78 [==============================] - 15s 186ms/step - loss: 0.0030 - mean_absolute_error: 0.0394
# Epoch 33/100
# 78/78 [==============================] - 15s 186ms/step - loss: 0.0030 - mean_absolute_error: 0.0392
# Epoch 34/100
# 78/78 [==============================] - 15s 196ms/step - loss: 0.0028 - mean_absolute_error: 0.0375
# Epoch 41/100
# 78/78 [==============================] - 16s 200ms/step - loss: 0.0027 - mean_absolute_error: 0.0375
# Epoch 42/100
# 78/78 [==============================] - 16s 209ms/step - loss: 0.0028 - mean_absolute_error: 0.0379
# Epoch 43/100
# 78/78 [==============================] - 16s 202ms/step - loss: 0.0028 - mean_absolute_error: 0.0376
# Epoch 44/100
# 78/78 [==============================] - 15s 196ms/step - loss: 0.0028 - mean_absolute_error: 0.0382
# Epoch 45/100
# 78/78 [==============================] - 15s 186ms/step - loss: 0.0030 - mean_absolute_error: 0.0388
# Epoch 46/100
# 78/78 [==============================] - 14s 185ms/step - loss: 0.0025 - mean_absolute_error: 0.0364
# Epoch 47/100
# 78/78 [==============================] - 15s 196ms/step - loss: 0.0027 - mean_absolute_error: 0.0376
# Epoch 48/100
# 78/78 [==============================] - 15s 196ms/step - loss: 0.0026 - mean_absolute_error: 0.0369
# Epoch 49/100
# 78/78 [==============================] - 16s 200ms/step - loss: 0.0027 - mean_absolute_error: 0.0375
# Epoch 50/100
# 78/78 [==============================] - 16s 202ms/step - loss: 0.0026 - mean_absolute_error: 0.0373
# Epoch 51/100
# 78/78 [==============================] - 16s 199ms/step - loss: 0.0026 - mean_absolute_error: 0.0373
# Epoch 52/100
# 78/78 [==============================] - 16s 199ms/step - loss: 0.0029 - mean_absolute_error: 0.0389
# Epoch 53/100
# 78/78 [==============================] - 16s 201ms/step - loss: 0.0025 - mean_absolute_error: 0.0364
# Epoch 54/100
# 78/78 [==============================] - 16s 202ms/step - loss: 0.0027 - mean_absolute_error: 0.0373
# Epoch 55/100
# 78/78 [==============================] - 16s 202ms/step - loss: 0.0028 - mean_absolute_error: 0.0380
# Epoch 56/100
# 78/78 [==============================] - 31s 399ms/step - loss: 0.0028 - mean_absolute_error: 0.0373
# Epoch 57/100
# 78/78 [==============================] - 15s 189ms/step - loss: 0.0027 - mean_absolute_error: 0.0373
# Epoch 58/100
# 78/78 [==============================] - 15s 187ms/step - loss: 0.0027 - mean_absolute_error: 0.0370
# Epoch 59/100
# 78/78 [==============================] - 15s 194ms/step - loss: 0.0026 - mean_absolute_error: 0.0373
# Epoch 60/100
# 78/78 [==============================] - 16s 200ms/step - loss: 0.0025 - mean_absolute_error: 0.0364
# Epoch 61/100
# 78/78 [==============================] - 16s 204ms/step - loss: 0.0025 - mean_absolute_error: 0.0356
# Epoch 62/100
# 78/78 [==============================] - 16s 206ms/step - loss: 0.0025 - mean_absolute_error: 0.0358
# Epoch 63/100
# 78/78 [==============================] - 16s 210ms/step - loss: 0.0026 - mean_absolute_error: 0.0370
# Epoch 64/100
# 78/78 [==============================] - 17s 220ms/step - loss: 0.0027 - mean_absolute_error: 0.0366
# Epoch 69/100
# 78/78 [==============================] - 17s 225ms/step - loss: 0.0026 - mean_absolute_error: 0.0364
# Epoch 70/100
# 78/78 [==============================] - 17s 222ms/step - loss: 0.0026 - mean_absolute_error: 0.0367
# Epoch 71/100
# 78/78 [==============================] - 17s 217ms/step - loss: 0.0025 - mean_absolute_error: 0.0359
# Epoch 72/100
# 78/78 [==============================] - 16s 210ms/step - loss: 0.0024 - mean_absolute_error: 0.0353
# Epoch 73/100
# 78/78 [==============================] - 16s 208ms/step - loss: 0.0025 - mean_absolute_error: 0.0355
# Epoch 74/100
# 78/78 [==============================] - 16s 205ms/step - loss: 0.0024 - mean_absolute_error: 0.0354
# Epoch 75/100
# 78/78 [==============================] - 16s 210ms/step - loss: 0.0027 - mean_absolute_error: 0.0376
# Epoch 76/100
# 78/78 [==============================] - 16s 209ms/step - loss: 0.0025 - mean_absolute_error: 0.0359
# Epoch 77/100
# 78/78 [==============================] - 16s 210ms/step - loss: 0.0025 - mean_absolute_error: 0.0356
# Epoch 78/100
# 78/78 [==============================] - 16s 211ms/step - loss: 0.0025 - mean_absolute_error: 0.0356
# Epoch 79/100
# 78/78 [==============================] - 16s 211ms/step - loss: 0.0028 - mean_absolute_error: 0.0380
# Epoch 80/100
# 78/78 [==============================] - 16s 211ms/step - loss: 0.0025 - mean_absolute_error: 0.0363
# Epoch 81/100
# 78/78 [==============================] - 16s 211ms/step - loss: 0.0026 - mean_absolute_error: 0.0368
# Epoch 82/100
# 78/78 [==============================] - 17s 217ms/step - loss: 0.0024 - mean_absolute_error: 0.0350
# Epoch 83/100
# 78/78 [==============================] - 16s 210ms/step - loss: 0.0025 - mean_absolute_error: 0.0358
# Epoch 84/100
# 78/78 [==============================] - 16s 211ms/step - loss: 0.0026 - mean_absolute_error: 0.0372
# Epoch 85/100
# 78/78 [==============================] - 17s 212ms/step - loss: 0.0026 - mean_absolute_error: 0.0362
# Epoch 86/100
# 78/78 [==============================] - 17s 215ms/step - loss: 0.0025 - mean_absolute_error: 0.0362
# Epoch 87/100
# 78/78 [==============================] - 17s 212ms/step - loss: 0.0024 - mean_absolute_error: 0.0345
# Epoch 88/100
# 78/78 [==============================] - 16s 210ms/step - loss: 0.0024 - mean_absolute_error: 0.0355
# Epoch 89/100
# 78/78 [==============================] - 16s 210ms/step - loss: 0.0026 - mean_absolute_error: 0.0364
# Epoch 90/100
# 78/78 [==============================] - 16s 210ms/step - loss: 0.0024 - mean_absolute_error: 0.0349
# Epoch 91/100
# 78/78 [==============================] - 17s 212ms/step - loss: 0.0023 - mean_absolute_error: 0.0350
# Epoch 92/100
# 78/78 [==============================] - 16s 210ms/step - loss: 0.0024 - mean_absolute_error: 0.0351
# Epoch 93/100
# 78/78 [==============================] - 16s 211ms/step - loss: 0.0024 - mean_absolute_error: 0.0353
# Epoch 94/100
# 78/78 [==============================] - 16s 210ms/step - loss: 0.0024 - mean_absolute_error: 0.0352
# Epoch 95/100
# 78/78 [==============================] - 16s 211ms/step - loss: 0.0025 - mean_absolute_error: 0.0352
# Epoch 96/100
# 78/78 [==============================] - 16s 210ms/step - loss: 0.0026 - mean_absolute_error: 0.0365
# Epoch 97/100
# 78/78 [==============================] - 17s 212ms/step - loss: 0.0023 - mean_absolute_error: 0.0346
# Epoch 98/100
# 78/78 [==============================] - 17s 213ms/step - loss: 0.0024 - mean_absolute_error: 0.0347
# Epoch 99/100
# 78/78 [==============================] - 16s 211ms/step - loss: 0.0024 - mean_absolute_error: 0.0348
# Epoch 100/100
# 78/78 [==============================] - 17s 214ms/step - loss: 0.0022 - mean_absolute_error: 0.0339

# %%
model.save('keras_model.h5')

# %%
test_close.shape
# Out:
# (1101, 1)

# %%
past_100_days = pd.DataFrame(train_close[-100:])

# %%
test_df = pd.DataFrame(test_close)

# %%
final_df = pd.concat([past_100_days, test_df], ignore_index=True)

# %%
final_df.head()
# Out:
#              0
# 0  2208.000000
# 1  2184.699951
# 2  2195.000000
# 3  2194.199951
# 4  2215.000000

# %%
input_data = scaler.fit_transform(final_df)
input_data
# Out:
# array([[0.23352017],
#        [0.22576886],
#        [0.22919542],
#        ...,
#        [0.88434608],
#        [0.87326795],
#        [0.86841105]])

# %%
input_data.shape
# Out:
# (1201, 1)

# %%
#Testing the model
x_test = []
y_test = []
for i in range(100, input_data.shape[0]):
   x_test.append(input_data[i-100: i])
   y_test.append(input_data[i, 0])

# %%
x_test, y_test = np.array(x_test), np.array(y_test)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1101, 100, 1)
# (1101,)

# %%
#Making prediction and plotting the graph of predicted vs actual values
# Making predictions

y_pred = model.predict(x_test)
# Out:
# 35/35 [==============================] - 2s 60ms/step

# %%
y_pred.shape
# Out:
# (1101, 1)

# %%
y_test
# Out:
# array([0.18877558, 0.18488332, 0.16798349, ..., 0.88434608, 0.87326795,
#        0.86841105])

# %%
y_pred
# Out:
# array([[0.22867532],
#        [0.23266195],
#        [0.23656751],
#        ...,
#        [0.86494523],
#        [0.87445676],
#        [0.8827194 ]], dtype=float32)

# %%
scaler.scale_
# Out:
# array([0.00033267])

# %%
scale_factor = 1/0.00041967
y_pred = y_pred * scale_factor
y_test = y_test * scale_factor

# %%
plt.figure(figsize = (12,6))
plt.plot(y_test, 'b', label = "Original Price")
plt.plot(y_pred, 'r', label = "Predicted Price")
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Model evaluation
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, y_pred)
mae_percentage = (mae / np.mean(y_test)) * 100
print("Mean absolute error on test set: {:.2f}%".format(mae_percentage))
# Out:
# Mean absolute error on test set: 4.94%

# %%
from sklearn.metrics import r2_score

# Actual values
actual = y_test

# Predicted values
predicted = y_pred

# Calculate the R2 score
r2 = r2_score(actual, predicted)

print("R2 score:", r2)
# Out:
# R2 score: 0.946279970936369

# %%
# Plotting the R2 score
fig, ax = plt.subplots()
ax.barh(0, r2, color='skyblue')
ax.set_xlim([-1, 1])
ax.set_yticks([])
ax.set_xlabel('R2 Score')
ax.set_title('R2 Score')

# Adding the R2 score value on the bar
ax.text(r2, 0, f'{r2:.2f}', va='center', color='black')

plt.show()

# %%
plt.scatter(actual, predicted)
plt.plot([min(actual), max(actual)], [min(predicted), max(predicted)], 'r--')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title(f'R2 Score: {r2:.2f}')
plt.show()
